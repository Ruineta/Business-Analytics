# %% [markdown]
# # Generate Final Report
#
# This notebook generates comprehensive reports and summaries of the analysis.

# %%
# Import libraries
import pandas as pd
import numpy as np
import sys
from pathlib import Path

# Add src to path
project_root = Path().resolve().parent
sys.path.append(str(project_root))

# Import custom utilities
from src.utils import load_data, get_data_path, generate_summary_report, generate_insights_json

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
# Load cleaned data
data_path = get_data_path('cleaned_data.csv', subfolder='processed')
df = load_data(data_path)

print(f"Data loaded: {df.shape}")
print(f"\nGenerating reports...")
# Out:
# Data loaded: (1470, 41)
#
# Generating reports...

# %%
# Generate summary report
report_path = generate_summary_report(df)
print(f"\n✓ Summary report generated: {report_path}")
# Out:
# Summary report saved to: C:\Users\ADMIN\Documents\GitHub\Business-Analytics\outputs\reports\summary_report_20251120_094323.txt
#
# ✓ Summary report generated: C:\Users\ADMIN\Documents\GitHub\Business-Analytics\outputs\reports\summary_report_20251120_094323.txt

# %%
# Generate insights JSON
insights_path = generate_insights_json(df)
print(f"\n✓ Insights JSON generated: {insights_path}")
# Out:
# Insights JSON saved to: C:\Users\ADMIN\Documents\GitHub\Business-Analytics\outputs\reports\insights_20251120_094328.json
#
# ✓ Insights JSON generated: C:\Users\ADMIN\Documents\GitHub\Business-Analytics\outputs\reports\insights_20251120_094328.json

# %% [markdown]
# ## Report Summary
#
# All reports have been generated and saved to the `outputs/reports/` directory.
